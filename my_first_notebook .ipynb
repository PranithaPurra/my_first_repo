# %% [markdown]
# Difference between Hardware and Software:
#
# Hardware: Physical components of the computer that we can see and touch
#
# Ex:Keyboard, CPU,Mouse
#
# Software: Programs or the instructions that tell the computer what to do
#
# Ex:Apps(whatsapp, instagram etc),Mobile games,chrome browser
